# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests

# %%
start = 2020
stop = 2021

# %% [markdown]
# # Let's use a for loop to secure the data from 2004 to today

# %%
for year in range(start,stop,1):
    site = 'https://www.basketball-reference.com/leagues/NBA_{}.html'
    tableID = 'team-stats-per_game'
    
    comm = re.compile("<!--|-->")
    url= site.format(year)
    file = "{}.csv"
    
    html = requests.get(url).text
    cleaned_soup = BeautifulSoup(re.sub("<!--|-->","", str(html)),'lxml')
    
    tableStats = cleaned_soup.find('table', {'id':tableID})
    
    headers = [th.getText() for th in tableStats.findAll('tr')[0].findAll('th')]
    headers = headers[1:]
    rows = tableStats.findAll('tr')[1:]
    stats = [[td.getText() for td in rows[i].findAll('td')]
                for i in range(len(rows))]
        
    stats = pd.DataFrame(stats, columns = headers)
    
    for col in stats:
        if col != 'Team':
            stats[col] = stats[col].rank()
            
    stats["Playoffs"] = ["1" if "*"  in ele else "0" for ele in stats["Team"]]
    
    if year == start:
        overallstats = stats
    if year != start:
        overallstats = overallstats.append(stats, ignore_index=True)

# %% [markdown]
# # So, now let's look at what stats we scraped:

# %%
overallstats
# Out:
#                       Team     G    MP    FG   FGA   FG%    3P   3PA   3P%  \
# 0         Dallas Mavericks  31.0  22.0  22.0  22.0  15.5  29.0  30.0  22.0
# 1         Milwaukee Bucks*  26.5   3.5  31.0  29.0  29.0  26.0  28.0  13.0
# 2         Houston Rockets*  17.5  13.0  20.0  25.0   9.0  30.0  31.0   9.0
# 3   Portland Trail Blazers  30.0   8.0  25.0  26.0  19.0  21.0  16.0  29.0
# 4    Los Angeles Clippers*  17.5   8.0  21.0  18.5  20.0  18.0  15.0  24.0
# 5     New Orleans Pelicans  17.5  23.0  28.0  31.0  18.0  27.5  26.0  25.5
# 6       Washington Wizards  17.5   8.0  24.0  27.5  15.5  16.5  14.0  25.5
# 7             Phoenix Suns  26.5   8.0  17.5   7.5  21.0  10.0  10.0  15.0
# 8        Memphis Grizzlies  26.5   3.5  30.0  27.5  23.0   6.0   7.0   7.5
# 9              Miami Heat*  26.5  31.0   5.0   1.0  25.0  25.0  22.0  31.0
# 10         Boston Celtics*  17.5  18.5  19.0  20.0  12.5  19.0  18.0  21.0
# 11     Los Angeles Lakers*   8.5   5.0  29.0  12.0  31.0   8.0   9.0  11.5
# 12       San Antonio Spurs   8.5  27.0  26.0  21.0  25.0   4.0   3.0  27.5
# 13           Atlanta Hawks  17.5  28.5  14.5  24.0   8.0  12.5  24.0   1.0
# 14         Indiana Pacers*  26.5  13.0  27.0  13.0  30.0   1.0   1.0  19.0
# 15        Toronto Raptors*   8.5  13.0  11.5   9.0  10.0  27.5  25.0  27.5
# 16           Brooklyn Nets  17.5  28.5   8.0  23.0   4.0  22.5  27.0   5.0
# 17              Utah Jazz*  17.5   1.5   8.0   2.0  27.0  22.5  20.0  30.0
# 18         Denver Nuggets*  17.5  25.5  23.0  17.0  25.0   5.0   5.0  14.0
# 19     Philadelphia 76ers*  17.5   8.0  17.5   6.0  22.0  11.0   8.0  19.0
# 20        Sacramento Kings  17.5  25.5  14.5  10.5  15.5  20.0  21.0  19.0
# 21  Oklahoma City Thunder*   8.5  18.5  10.0   3.0  28.0   3.0   4.0  16.0
# 22           Orlando Magic  26.5   1.5   4.0  14.5   5.0   7.0  12.0   6.0
# 23  Minnesota Timberwolves   1.0  30.0  13.0  30.0   3.0  24.0  29.0   3.0
# 24         Detroit Pistons   8.5  18.5   3.0   4.0  12.5  12.5  13.0  23.0
# 25         New York Knicks   8.5  18.5   8.0  18.5   6.5  31.0   2.0   4.0
# 26     Cleveland Cavaliers   3.5  18.5  11.5   7.5  11.0   9.0  11.0  10.0
# 27           Chicago Bulls   3.5  11.0   6.0  14.5   6.5  16.5  23.0   7.5
# 28   Golden State Warriors   3.5  18.5   2.0  10.5   2.0   2.0   6.0   2.0
# 29       Charlotte Hornets   3.5  24.0   1.0   5.0   1.0  14.5  19.0  11.5
# 30          League Average  17.5  15.0  16.0  16.0  15.5  14.5  17.0  17.0
#
#       2P  ...   ORB   DRB   TRB   AST   STL   BLK   TOV    PF   PTS  Playoffs
# 0    4.0  ...  12.5  28.0  28.0  18.0   4.0  15.5   3.5   7.0  29.0         0
# 1   24.5  ...  26.5  31.0  31.0  25.0  10.5  29.0  22.0   5.5  31.0         1
# 2    2.0  ...   5.0  14.5  16.0   2.0  28.5  20.0  12.5  24.5  30.0         1
# 3   20.0  ...   3.5  20.5  22.0   1.0   3.0  30.0   5.0  23.0  25.0         0
# 4   18.5  ...  15.5  29.0  29.0  10.0   8.0  15.5  17.0  27.0  28.0         1
# 5   15.0  ...  19.0  24.0  27.0  29.0  15.5  18.0  30.0  18.0  27.0         0
# 6   23.0  ...   1.5   2.0   1.5  20.5  22.0   7.0   9.0  30.0  26.0         0
# 7   22.0  ...  29.0   8.5   9.0  31.0  19.5   2.0  20.0  29.0  20.0         0
# 8   30.0  ...   6.5  27.0  25.0  30.0  21.0  26.0  24.0  19.0  18.0         0
# 9    3.0  ...  22.0  25.0  13.0  26.5  12.5   9.0  18.5  13.0  17.0         1
# 10  15.0  ...  12.5  19.0  23.0   6.0  26.5  26.0   7.0  21.0  21.0         1
# 11  28.5  ...   9.5  20.5  24.0  22.5  28.5  31.0  22.0  15.0  24.0         1
# 12  28.5  ...  24.5  22.0  14.5  19.0   9.0  24.0   1.0   5.5  23.0         0
# 13  15.0  ...  31.0   8.5  10.0  13.0  19.5  20.0  29.0  31.0  16.0         0
# 14  31.0  ...  23.0  11.0   5.0  26.5  10.5  22.0   3.5   8.0   9.0         1
# 15   5.0  ...  26.5  23.0  20.0  20.5  31.0  15.5  15.5  22.0  19.0         1
# 16   7.5  ...  15.5  30.0  30.0  16.0   5.0   9.0  26.0  16.5  14.0         0
# 17   6.0  ...  24.5  26.0  19.0   4.5   2.0   3.0  22.0  11.0  12.0         1
# 18  27.0  ...  15.5   8.5  11.5  28.0  23.5  11.5   8.0  12.0  11.0         1
# 19  21.0  ...   9.5  18.0  21.0  24.0  23.5  23.0  10.5  16.5  10.0         1
# 20  11.0  ...  28.0   5.5   4.0   9.0  18.0   5.0  12.5  27.0   8.0         0
# 21  24.5  ...  21.0  16.0   6.0   3.0  15.5  20.0   6.0   4.0  13.0         1
# 22  13.0  ...   6.5  12.0  14.5  14.5  26.5  26.0   2.0   1.0   6.0         0
# 23   7.5  ...   9.5  13.0  17.5  11.5  30.0  28.0  26.0  20.0  22.0         0
# 24   9.0  ...  30.0   4.0   1.5  14.5  12.5   9.0  26.0   9.0   7.0         0
# 25  26.0  ...  20.0  14.5  26.0   4.5  15.5  13.0  10.5  27.0   2.0         0
# 26  18.5  ...  15.5   8.5  11.5   7.0   7.0   1.0  31.0   2.0   5.0         0
# 27  10.0  ...   9.5   1.0   3.0   8.0   1.0   5.0  28.0  24.5   4.0         0
# 28  12.0  ...   1.5   5.5   7.5  22.5  25.0  11.5  18.5  10.0   3.0         0
# 29   1.0  ...  18.0   3.0   7.5  11.5   6.0   5.0  15.5   3.0   1.0         0
# 30  17.0  ...   3.5  17.0  17.5  17.0  15.5  15.5  14.0  14.0  15.0         0
#
# [31 rows x 25 columns]

# %% [markdown]
# # Now let's clean up the data for just what stats matter

# %%
overallstats = overallstats[~overallstats['Team'].str.contains("League Average")]
overallstats = overallstats[['3P%','2P%','DRB','AST','STL','BLK','TOV','PF','Playoffs']]

# %%
overallstats
# Out:
#      3P%   2P%   DRB   AST   STL   BLK   TOV    PF Playoffs
# 0   22.0  28.0  28.0  18.0   4.0  15.5   3.5   7.0        0
# 1   13.0  31.0  31.0  25.0  10.5  29.0  22.0   5.5        1
# 2    9.0  29.0  14.5   2.0  28.5  20.0  12.5  24.5        1
# 3   29.0   7.0  20.5   1.0   3.0  30.0   5.0  23.0        0
# 4   24.0  13.0  29.0  10.0   8.0  15.5  17.0  27.0        1
# 5   25.5  17.0  24.0  29.0  15.5  18.0  30.0  18.0        0
# 6   25.5   5.5   2.0  20.5  22.0   7.0   9.0  30.0        0
# 7   15.0  21.0   8.5  31.0  19.5   2.0  20.0  29.0        0
# 8    7.5  24.5  27.0  30.0  21.0  26.0  24.0  19.0        0
# 9   31.0  24.5  25.0  26.5  12.5   9.0  18.5  13.0        1
# 10  21.0  10.5  19.0   6.0  26.5  26.0   7.0  21.0        1
# 11  11.5  30.0  20.5  22.5  28.5  31.0  22.0  15.0        1
# 12  27.5   9.0  22.0  19.0   9.0  24.0   1.0   5.5        0
# 13   1.0  20.0   8.5  13.0  19.5  20.0  29.0  31.0        0
# 14  19.0  22.5  11.0  26.5  10.5  22.0   3.5   8.0        1
# 15  27.5  10.5  23.0  20.5  31.0  15.5  15.5  22.0        1
# 16   5.0  13.0  30.0  16.0   5.0   9.0  26.0  16.5        0
# 17  30.0  27.0  26.0   4.5   2.0   3.0  22.0  11.0        1
# 18  14.0  22.5   8.5  28.0  23.5  11.5   8.0  12.0        1
# 19  19.0  19.0  18.0  24.0  23.5  23.0  10.5  16.5        1
# 20  19.0  17.0   5.5   9.0  18.0   5.0  12.5  27.0        0
# 21  16.0  26.0  16.0   3.0  15.5  20.0   6.0   4.0        1
# 22   6.0   4.0  12.0  14.5  26.5  26.0   2.0   1.0        0
# 23   3.0  15.0  13.0  11.5  30.0  28.0  26.0  20.0        0
# 24  23.0   8.0   4.0  14.5  12.5   9.0  26.0   9.0        0
# 25   4.0   3.0  14.5   4.5  15.5  13.0  10.5  27.0        0
# 26  10.0  13.0   8.5   7.0   7.0   1.0  31.0   2.0        0
# 27   7.5   5.5   1.0   8.0   1.0   5.0  28.0  24.5        0
# 28   2.0   2.0   5.5  22.5  25.0  11.5  18.5  10.0        0
# 29  11.5   1.0   3.0  11.5   6.0   5.0  15.5   3.0        0

# %%
overallstats.to_csv(f"statsfor{start}to{stop}.csv",index=False)
